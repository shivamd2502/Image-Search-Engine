# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/satellite-image-classification/data/cloudy/train_17406.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_28684.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_33597.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_34079.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_30586.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_18281.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_33296.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_34303.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_1336.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_30792.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_19000.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_13047.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_21750.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_39492.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_20483.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_14542.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_16567.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_179.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_32009.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_12770.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_15350.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_34208.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_9761.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_39361.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_9021.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_13404.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_534.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_29808.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_29278.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_22027.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_6630.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_11871.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_17584.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_38823.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_15747.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_37070.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_20523.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_8658.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_13497.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_14179.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_4205.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_7387.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_34831.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_5925.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_7759.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_17569.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_13248.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_17357.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_30828.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_2118.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_14210.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_37942.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_39830.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_35475.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_35753.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_1786.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_25389.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_12611.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_39527.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_31228.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_14654.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_17301.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_2562.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_32670.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_20177.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_26572.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_4476.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_28832.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_38089.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_30764.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_39256.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_16659.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_29424.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_26015.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_23884.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_14060.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_25647.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_4438.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_24350.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_33510.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_1738.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_24192.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_3589.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_6681.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_12112.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_18402.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_16735.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_5220.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_37841.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_10793.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_34507.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_1598.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_7708.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_14978.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_8731.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_24945.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_15396.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_33425.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_25602.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_17643.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_9868.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_1698.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_34936.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_10540.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_24991.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_36559.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_8544.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_17182.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_2965.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_15171.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_8871.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_37592.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_2231.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_2655.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_2904.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_20756.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_5180.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_6105.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_11492.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_38217.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_11283.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_1092.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_15677.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_19392.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_2796.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_13407.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_31369.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_11008.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_10389.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_16531.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_10816.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_32431.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_33962.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_12009.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_3684.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_168.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_24237.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_28485.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_10889.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_1793.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_20894.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_29732.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_11294.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_11706.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_27810.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_11218.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_27545.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_35506.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_22160.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_22175.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_32320.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_24139.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_25626.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_27254.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_21388.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_11981.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_36537.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_22808.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_14175.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_2900.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_36321.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_26562.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_36529.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_8064.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_28444.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_37190.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_3368.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_1492.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_13413.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_11047.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_30724.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_13887.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_31384.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_9300.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_8840.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_14107.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_18887.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_28522.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_8239.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_10263.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_10952.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_11240.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_20864.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_10710.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_28329.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_11644.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_19911.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_39028.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_6856.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_21908.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_37900.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_28318.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_22865.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_38757.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_18768.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_16031.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_31527.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_13300.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_2337.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_28197.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_12975.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_8458.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_17797.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_860.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_13464.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_22369.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_9783.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_24636.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_1360.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_8836.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_38073.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_2366.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_902.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_11686.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_3849.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_5047.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_31197.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_13628.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_30083.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_23478.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_22967.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_3278.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_21591.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_39653.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_29504.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_20356.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_11561.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_11132.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_33523.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_35495.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_35426.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_1086.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_1580.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_24249.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_2006.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_3835.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_23252.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_23826.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_7121.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_14404.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_24031.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_14835.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_14090.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_27921.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_23980.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_20601.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_29550.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_16575.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_26416.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_77.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_17702.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_6954.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_18672.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_15165.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_23843.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_34163.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_32309.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_15885.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_17662.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_10666.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_20703.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_31979.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_37623.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_18386.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_38166.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_28182.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_14024.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_6888.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_5235.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_5572.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_4873.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_22728.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_15489.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_29016.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_16195.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_18821.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_35179.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_26443.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_34534.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_10642.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_16628.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_21806.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_31756.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_20612.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_33973.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_14942.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_23312.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_3366.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_1722.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_27120.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_21888.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_23081.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_19085.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_16935.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_8546.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_15351.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_984.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_40416.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_28936.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_39863.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_18954.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_16997.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_14034.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_37563.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_4998.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_36545.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_32433.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_11896.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_21364.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_7192.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_37683.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_8370.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_8816.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_39385.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_28534.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_21872.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_38108.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_25953.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_15622.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_970.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_22371.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_19299.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_24094.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_16947.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_23490.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_31129.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_32375.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_18572.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_25041.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_31368.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_1490.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_17556.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_8232.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_5557.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_21385.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_10563.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_20008.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_28089.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_30862.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_23443.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_10566.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_3327.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_23222.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_38833.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_19442.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_15477.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_4256.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_15868.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_32139.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_12239.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_8198.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_36004.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_10225.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_16486.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_23646.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_29002.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_8961.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_34585.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_21555.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_21335.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_6438.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_15709.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_9229.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_36520.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_108.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_27527.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_25176.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_6073.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_10201.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_14659.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_12058.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_22809.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_14591.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_18102.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_8013.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_24917.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_27397.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_9852.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_16927.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_2699.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_13613.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_24490.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_17549.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_38893.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_16023.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_20826.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_20748.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_29292.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_15862.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_15590.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_343.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_35883.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_30534.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_5675.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_23981.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_13129.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_6802.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_5021.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_24989.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_18661.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_22041.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_1378.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_4116.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_32330.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_38788.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_20397.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_19756.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_10856.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_11211.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_5206.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_18862.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_32802.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_11150.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_12701.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_4349.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_16915.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_29523.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_25827.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_3932.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_12517.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_40203.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_20675.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_18860.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_646.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_7440.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_38925.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_27239.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_12682.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_32799.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_24472.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_22123.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_32869.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_24724.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_3645.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_27556.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_37423.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_34888.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_26643.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_26216.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_13312.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_28831.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_1520.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_11354.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_22193.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_4717.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_19513.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_24299.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_39500.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_33140.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_31954.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_20077.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_39520.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_31869.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_21871.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_28851.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_25818.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_20821.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_31242.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_3512.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_30155.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_10609.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_12360.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_14238.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_33639.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_6279.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_40475.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_13219.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_16397.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_20069.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_13292.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_10581.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_11259.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_40327.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_25815.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_29881.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_33341.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_10547.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_26485.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_16059.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_10667.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_36058.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_19785.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_28432.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_19386.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_9770.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_36945.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_33481.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_17610.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_8421.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_1968.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_16844.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_1717.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_9844.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_24640.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_3176.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_19502.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_29187.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_3136.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_34125.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_37903.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_31713.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_38446.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_33260.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_16042.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_17622.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_35987.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_23566.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_1339.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_8588.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_26564.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_1483.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_24280.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_10177.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_25747.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_4626.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_3128.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_18355.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_6306.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_24829.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_10128.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_2431.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_25659.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_9499.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_14462.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_8481.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_36603.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_1670.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_28292.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_16213.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_28215.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_24443.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_20250.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_30686.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_30364.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_1782.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_3099.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_4094.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_4809.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_30949.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_35457.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_15830.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_118.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_5025.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_30056.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_29667.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_1756.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_22386.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_19504.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_22263.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_23877.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_23598.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_893.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_33933.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_38650.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_19621.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_16901.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_20352.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_17237.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_18417.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_601.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_18513.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_26460.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_1916.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_39821.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_1060.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_19027.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_18976.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_21016.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_31892.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_14592.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_23636.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_13167.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_9950.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_16199.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_21706.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_17141.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_21071.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_23417.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_28919.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_15993.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_20895.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_22590.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_32011.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_34728.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_18150.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_38405.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_10421.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_30798.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_29956.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_23403.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_16890.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_1479.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_17897.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_32613.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_12737.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_26892.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_20688.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_37879.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_33524.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_24303.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_8319.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_11307.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_39946.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_28454.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_16188.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_352.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_32819.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_25029.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_21788.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_38153.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_24301.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_24080.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_15254.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_32828.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_19813.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_38263.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_437.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_26.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_32385.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_16604.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_29833.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_27884.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_5458.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_17253.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_18658.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_10326.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_1391.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_39056.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_1070.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_8101.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_39892.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_1933.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_18444.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_13124.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_19694.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_28923.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_453.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_22773.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_38400.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_20522.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_6893.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_28244.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_32973.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_20179.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_26722.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_22582.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_7419.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_40236.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_23978.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_12038.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_3857.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_4867.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_30614.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_12525.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_6987.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_2163.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_14977.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_2396.jpg
# /kaggle/input/satellite-image-classification/data/cloudy/train_15247.jpg
# ...
# /kaggle/input/satellite-image-classification/data/water/SeaLake_1672.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_1766.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_2841.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_1630.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_1156.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_2111.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_743.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_2694.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_675.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_21.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_2753.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_654.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_986.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_2733.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_2392.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_1983.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_1191.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_649.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_2882.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_956.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_817.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_2460.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_1441.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_1046.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_1367.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_943.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_1313.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_1220.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_287.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_1569.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_2546.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_2641.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_1824.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_285.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_2692.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_221.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_2785.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_762.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_2236.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_1776.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_922.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_2957.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_1961.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_2491.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_708.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_1666.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_1336.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_1858.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_2311.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_796.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_450.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_1350.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_2327.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_369.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_2298.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_482.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_2538.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_930.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_965.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_2517.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_611.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_2168.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_2832.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_952.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_1094.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_75.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_2401.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_2467.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_1777.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_2471.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_459.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_2946.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_2179.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_1611.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_92.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_2995.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_2441.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_1692.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_1145.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_814.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_453.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_616.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_1919.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_645.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_800.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_1867.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_2320.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_1338.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_121.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_840.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_2288.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_3.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_1348.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_1627.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_2976.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_2922.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_1178.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_1310.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_2286.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_1004.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_2182.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_2651.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_2175.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_2817.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_898.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_1967.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_966.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_277.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_1294.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_2818.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_780.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_225.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_475.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_1195.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_2316.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_2592.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_1646.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_1329.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_1702.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_758.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_1381.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_585.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_2225.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_757.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_2.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_20.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_1108.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_1976.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_2905.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_746.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_568.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_1752.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_237.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_960.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_218.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_216.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_2258.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_587.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_2377.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_54.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_945.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_741.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_689.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_2222.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_2256.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_118.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_1358.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_257.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_290.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_379.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_1633.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_2897.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_1034.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_333.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_2673.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_264.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_994.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_1634.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_1316.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_980.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_1199.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_837.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_476.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_733.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_1190.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_2358.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_2819.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_256.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_99.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_2760.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_1330.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_1870.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_1447.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_252.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_831.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_1098.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_1847.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_2730.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_1141.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_750.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_571.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_153.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_2989.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_1674.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_624.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_736.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_2685.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_752.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_2705.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_1414.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_768.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_202.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_857.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_693.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_203.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_405.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_2858.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_541.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_802.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_1507.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_720.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_7.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_2591.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_131.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_2763.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_2468.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_2134.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_885.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_1510.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_658.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_1406.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_599.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_842.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_697.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_2719.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_682.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_1614.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_1184.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_1427.jpg
# /kaggle/input/satellite-image-classification/data/water/SeaLake_2146.jpg

# %%
# !pip install ftfy regex tqdm git+https://github.com/openai/CLIP.git
# Out:
# Collecting git+https://github.com/openai/CLIP.git
#   Cloning https://github.com/openai/CLIP.git to /tmp/pip-req-build-0x2hscor
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /tmp/pip-req-build-0x2hscor
#   Resolved https://github.com/openai/CLIP.git to commit dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: ftfy in /usr/local/lib/python3.11/dist-packages (6.3.1)
# Requirement already satisfied: regex in /usr/local/lib/python3.11/dist-packages (2025.11.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from ftfy) (0.2.13)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from clip==1.0) (25.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from clip==1.0) (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (from clip==1.0) (0.21.0+cu124)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (4.15.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (2025.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->clip==1.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->clip==1.0) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision->clip==1.0) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision->clip==1.0) (11.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->clip==1.0) (3.0.3)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision->clip==1.0) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision->clip==1.0) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision->clip==1.0) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision->clip==1.0) (2025.3.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision->clip==1.0) (2022.3.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision->clip==1.0) (2.4.1)
# Requirement already satisfied: onemkl-license==2025.3.0 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torchvision->clip==1.0) (2025.3.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torchvision->clip==1.0) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torchvision->clip==1.0) (2022.3.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->torchvision->clip==1.0) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->torchvision->clip==1.0) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->torchvision->clip==1.0) (2024.2.0)
# Building wheels for collected packages: clip
#   Building wheel for clip (setup.py) ... done
#   Created wheel for clip: filename=clip-1.0-py3-none-any.whl size=1369490 sha256=601b95602bfa42f3babe321d450c168772f6f97cbe8e1bff1c21503c5fae7acc
#   Stored in directory: /tmp/pip-ephem-wheel-cache-eo3m7qxc/wheels/3f/7c/a4/9b490845988bf7a4db33674d52f709f088f64392063872eb9a
# Successfully built clip
# Installing collected packages: clip
# Successfully installed clip-1.0

# %%
# Cell 0 (imports)
import os
import random
import clip
import torch
import numpy as np
from PIL import Image
from torch import nn
from torch.utils.data import Dataset, DataLoader, random_split
import torch.nn.functional as F
import torch.optim as optim
from tqdm import tqdm
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report

# %%
# Cell 1
device = "cuda" if torch.cuda.is_available() else "cpu"
print("Device:", device)

RND_SEED = 42
random.seed(RND_SEED)
np.random.seed(RND_SEED)
torch.manual_seed(RND_SEED)
if device == "cuda":
    torch.cuda.manual_seed_all(RND_SEED)
# Out:
# Device: cuda

# %%
# Cell 2
# Provide your dataset root path (folder with subfolders cloudy, desert, green_area, water)
DATA_ROOT = "/kaggle/input/satellite-image-classification/data"

# Load CLIP once here to get preprocess transform (do not repeatedly call clip.load)
_clip_model_tmp, preprocess = clip.load("ViT-B/32", device=device)

class SatelliteDataset(Dataset):
    def __init__(self, root, preprocess):
        self.root = root
        self.preprocess = preprocess
        # classes are folder names (sorted)
        self.classes = sorted([d for d in os.listdir(root) if os.path.isdir(os.path.join(root, d))])
        self.images = []
        self.labels = []
        for i, cls in enumerate(self.classes):
            folder = os.path.join(root, cls)
            for fname in os.listdir(folder):
                if fname.lower().endswith(("png","jpg","jpeg")):
                    self.images.append(os.path.join(folder, fname))
                    self.labels.append(i)

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        path = self.images[idx]
        img = Image.open(path).convert("RGB")
        img = self.preprocess(img)   # already a torch.Tensor
        label = self.labels[idx]
        return img, label

# %%
# Cell 3
full_dataset = SatelliteDataset(DATA_ROOT, preprocess)
print("Classes:", full_dataset.classes)
print("Total images:", len(full_dataset))

# split ratios
train_ratio = 0.7
val_ratio = 0.15
test_ratio = 0.15

n = len(full_dataset)
n_train = int(train_ratio * n)
n_val = int(val_ratio * n)
n_test = n - n_train - n_val

train_dataset, val_dataset, test_dataset = random_split(
    full_dataset, [n_train, n_val, n_test],
    generator=torch.Generator().manual_seed(RND_SEED)
)

print(f"Split sizes — train: {len(train_dataset)}, val: {len(val_dataset)}, test: {len(test_dataset)}")
# Out:
# Classes: ['cloudy', 'desert', 'green_area', 'water']
# Total images: 5631
# Split sizes — train: 3941, val: 844, test: 846

# %%
# Cell 4
BATCH_SIZE = 32

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=2, pin_memory=True)
val_loader   = DataLoader(val_dataset,   batch_size=BATCH_SIZE, shuffle=False, num_workers=2, pin_memory=True)
test_loader  = DataLoader(test_dataset,  batch_size=BATCH_SIZE, shuffle=False, num_workers=2, pin_memory=True)

# %%
# Cell 5
class_prompts = {
    "cloudy": [
        "a satellite image of a cloudy region",
        "an aerial view covered with clouds",
        "a satellite photo showing heavy cloud cover",
        "a top-down image with dense clouds",
        "a satellite scene with scattered clouds",
        "an overhead view showing thick clouds",
        "a cloudy sky captured from space",
        "a satellite observation of cloudy weather",
        "aerial imagery showing cloud patches",
        "a satellite frame showing overcast conditions"
    ],
    "desert": [
        "a satellite image of a desert region",
        "an aerial view of sandy desert terrain",
        "a top-down satellite photo of dry desert land",
        "a satellite scene showing barren desert",
        "a satellite view of sand dunes",
        "aerial imagery of an arid desert landscape",
        "a desert area captured from space",
        "a satellite frame showing dry, sandy terrain",
        "an overhead image of vast desert land",
        "a satellite photo of a hot, dry desert"
    ],
    "green_area": [
        "a satellite image of green vegetation",
        "an aerial view of dense green forest",
        "a satellite photo showing lush green land",
        "a top-down view of agricultural green fields",
        "a satellite scene showing vegetation cover",
        "a satellite frame of forested area",
        "aerial imagery of green terrain",
        "a satellite view showing high vegetation density",
        "an overhead image of green landscape",
        "a satellite image of farming land with greenery"
    ],
    "water": [
        "a satellite image of a water body",
        "an aerial view of a river or lake",
        "a satellite photo of an ocean region",
        "a top-down view of blue water",
        "a satellite scene showing rivers and lakes",
        "a satellite frame capturing large water bodies",
        "aerial imagery of a coastline or sea",
        "a satellite image showing clear blue water",
        "an overhead view of aquatic regions",
        "a satellite photo showing water surfaces"
    ]
}

# Ensure keys match dataset classes
print("Dataset classes:", full_dataset.classes)
for cls in full_dataset.classes:
    if cls not in class_prompts:
        raise ValueError(f"No prompts provided for class '{cls}' — add prompts to class_prompts.")
# Out:
# Dataset classes: ['cloudy', 'desert', 'green_area', 'water']

# %%
# Cell 6
class CLIPWithHeads(nn.Module):
    def __init__(self, classes, class_prompts, num_classes, device="cuda"):
        super().__init__()
        self.classes = classes
        self.class_prompts = class_prompts
        self.device = device

        # Load CLIP once here (we already called clip.load earlier for preprocess)
        self.clip_model, _ = clip.load("ViT-B/32", device=device)
        # force fp32 to avoid dtype mismatch with adapter
        self.clip_model.float()

        embed_dim = self.clip_model.visual.output_dim  # 512

        # Freeze CLIP parameters
        for p in self.clip_model.parameters():
            p.requires_grad = False

        # Adapter (trainable)
        self.adapter = nn.Sequential(
            nn.Linear(embed_dim, embed_dim),
            nn.ReLU(),
            nn.Linear(embed_dim, embed_dim)
        )

        # Classifier heads
        self.image_head = nn.Linear(embed_dim, num_classes)
        self.text_head  = nn.Linear(embed_dim, num_classes)

        # Trainable temperature (logit scale)
        self.logit_scale = nn.Parameter(torch.tensor(1.0))

    def encode_image(self, images):
        # images: tensor [B, C, H, W]
        with torch.no_grad():
            x = self.clip_model.encode_image(images)   # usually fp16 on GPU, but we forced float()
        x = x.float()
        x = self.adapter(x)   # adapter in fp32
        x = x / x.norm(dim=-1, keepdim=True)
        return x

    def encode_text(self, text_tokens):
        # text_tokens: tokenized batch
        with torch.no_grad():
            x = self.clip_model.encode_text(text_tokens)
        x = x.float()
        x = x / x.norm(dim=-1, keepdim=True)
        return x

    def prompt_batch_embeddings(self, class_ids):
        """
        Given a list/1D-tensor of class indices (length B), create a batch of prompts,
        tokenize once, and return text embeddings of shape [B, D].
        """
        prompts = []
        for cid in class_ids:
            cname = self.classes[int(cid)]
            prompt = random.choice(self.class_prompts[cname])
            prompts.append(prompt)
        tokens = clip.tokenize(prompts).to(self.device)   # batched tokenization
        return self.encode_text(tokens)

# %%
# Cell 7
num_classes = len(full_dataset.classes)
model = CLIPWithHeads(classes=full_dataset.classes, class_prompts=class_prompts, num_classes=num_classes, device=device).to(device)

# Train only adapter + heads + logit_scale
trainable = list(model.adapter.parameters()) + list(model.image_head.parameters()) + list(model.text_head.parameters()) + [model.logit_scale]
optimizer = optim.AdamW(trainable, lr=2e-4, weight_decay=0.01)
scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=10)

# %%
# Cell 8
def train_one_epoch(model, loader, optimizer, device):
    model.train()
    losses = []
    for images, labels in tqdm(loader, leave=False):
        images = images.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()
        # image features
        img_feat = model.encode_image(images)        # [B, D]
        # text features (batched prompts matching labels)
        text_feat = model.prompt_batch_embeddings(labels)  # [B, D]

        scale = model.logit_scale.exp()
        logits_per_image = scale * img_feat @ text_feat.T   # [B, B]
        logits_per_text  = logits_per_image.T               # [B, B]
        targets = torch.arange(images.size(0), device=device)

        # contrastive loss (image->text and text->image)
        loss_i = F.cross_entropy(logits_per_image, targets)
        loss_t = F.cross_entropy(logits_per_text, targets)
        contrastive_loss = (loss_i + loss_t) / 2.0

        # classification heads (match each embedding to its label)
        img_logits = model.image_head(img_feat)   # [B, num_classes]
        text_logits = model.text_head(text_feat)  # [B, num_classes]
        ce_img = F.cross_entropy(img_logits, labels)
        ce_text = F.cross_entropy(text_logits, labels)
        classification_loss = (ce_img + ce_text) / 2.0

        loss = contrastive_loss + classification_loss
        loss.backward()
        optimizer.step()

        losses.append(loss.item())
    return np.mean(losses)


def validate(model, loader, device):
    model.eval()
    losses = []
    all_preds = []
    all_labels = []
    with torch.no_grad():
        for images, labels in tqdm(loader, leave=False):
            images = images.to(device)
            labels = labels.to(device)

            img_feat = model.encode_image(images)
            text_feat = model.prompt_batch_embeddings(labels)

            scale = model.logit_scale.exp()
            logits_per_image = scale * img_feat @ text_feat.T
            logits_per_text  = logits_per_image.T
            targets = torch.arange(images.size(0), device=device)

            loss_i = F.cross_entropy(logits_per_image, targets)
            loss_t = F.cross_entropy(logits_per_text, targets)
            contrastive_loss = (loss_i + loss_t) / 2.0

            img_logits = model.image_head(img_feat)
            text_logits = model.text_head(text_feat)
            ce_img = F.cross_entropy(img_logits, labels)
            ce_text = F.cross_entropy(text_logits, labels)
            classification_loss = (ce_img + ce_text) / 2.0

            loss = contrastive_loss + classification_loss
            losses.append(loss.item())

            preds = img_logits.argmax(dim=1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    avg_loss = np.mean(losses)
    acc = 100.0 * (np.array(all_preds) == np.array(all_labels)).mean()
    return avg_loss, acc

# %%
# Cell 9
EPOCHS = 5
best_val_acc = 0.0
ckpt_path = "/kaggle/working/best_model.pt"

for epoch in range(EPOCHS):
    train_loss = train_one_epoch(model, train_loader, optimizer, device)
    val_loss, val_acc = validate(model, val_loader, device)
    scheduler.step()

    print(f"Epoch {epoch+1}/{EPOCHS}  TrainLoss: {train_loss:.4f}  ValLoss: {val_loss:.4f}  ValAcc: {val_acc:.2f}%")

    if val_acc > best_val_acc:
        best_val_acc = val_acc
        torch.save({
            'epoch': epoch,
            'model_state': model.state_dict(),
            'optimizer_state': optimizer.state_dict(),
            'val_acc': val_acc,
            'classes': full_dataset.classes
        }, ckpt_path)
        print("Saved best model.")
# Out:
# Epoch 1/5  TrainLoss: 4.2192  ValLoss: 3.9684  ValAcc: 99.17%
# Saved best model.
# Epoch 2/5  TrainLoss: 3.8758  ValLoss: 3.7514  ValAcc: 99.76%
# Saved best model.
# Epoch 3/5  TrainLoss: 3.7004  ValLoss: 3.6143  ValAcc: 99.88%
# Saved best model.
# Epoch 4/5  TrainLoss: 3.5793  ValLoss: 3.5114  ValAcc: 99.76%
# Epoch 5/5  TrainLoss: 3.4952  ValLoss: 3.4411  ValAcc: 100.00%
# Saved best model.

# %%
# Cell 10
ckpt = torch.load(
    "/kaggle/working/best_model.pt",
    map_location=device,
    weights_only=False   # ← REQUIRED for PyTorch 2.6+
)

model.load_state_dict(ckpt['model_state'])
model.to(device)
print("Loaded checkpoint — best val acc:", ckpt['val_acc'])

# Evaluate on test set: compute accuracy + classification report
def eval_and_report(loader, model, device, classes):
    model.eval()
    all_preds = []
    all_labels = []
    with torch.no_grad():
        for images, labels in loader:
            images = images.to(device); labels = labels.to(device)
            feats = model.encode_image(images)
            logits = model.image_head(feats)
            preds = logits.argmax(dim=1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    acc = 100.0 * (np.array(all_preds) == np.array(all_labels)).mean()
    print(f"Accuracy: {acc:.2f}%")
    print("\nClassification Report:")
    print(classification_report(all_labels, all_preds, target_names=classes))
    return np.array(all_labels), np.array(all_preds)

y_true, y_pred = eval_and_report(test_loader, model, device, full_dataset.classes)
# Out:
# Loaded checkpoint — best val acc: 100.0
# Accuracy: 99.88%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       cloudy       1.00      1.00      1.00       230
#       desert       1.00      1.00      1.00       173
#   green_area       1.00      1.00      1.00       224
#        water       1.00      1.00      1.00       219
#
#     accuracy                           1.00       846
#    macro avg       1.00      1.00      1.00       846
# weighted avg       1.00      1.00      1.00       846

# %%
# Cell 11
# Confusion matrix for train set (use train_loader)
train_labels, train_preds = [], []
with torch.no_grad():
    for images, labels in train_loader:
        images = images.to(device)
        feats = model.encode_image(images)
        logits = model.image_head(feats)
        preds = logits.argmax(dim=1)
        train_preds.extend(preds.cpu().numpy())
        train_labels.extend(labels.numpy())

train_cm = confusion_matrix(train_labels, train_preds)
plt.figure(figsize=(7,7))
disp = ConfusionMatrixDisplay(train_cm, display_labels=full_dataset.classes)
disp.plot(cmap="Blues", values_format="d")
plt.title("Confusion Matrix - Train Set")
plt.show()

# Confusion matrix for test set (we already computed y_true,y_pred)
test_cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(7,7))
disp = ConfusionMatrixDisplay(test_cm, display_labels=full_dataset.classes)
disp.plot(cmap="Greens", values_format="d")
plt.title("Confusion Matrix - Test Set")
plt.show()

# %%
# Cell 12
def predict_image(image_path, model, classes):
    img = Image.open(image_path).convert("RGB")
    img_t = preprocess(img).unsqueeze(0).to(device)
    with torch.no_grad():
        feat = model.encode_image(img_t)
        logits = model.image_head(feat)
        pred = logits.argmax(dim=1).item()

    return classes[pred]

# usage example:
# print(predict_image("/kaggle/input/.../cloudy/example.jpg", model, full_dataset.classes))
